# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Search query for amazon

# %%
search_query= "vivo"

# %%
base_url =  "https://www.amazon.com/s?k="

# %%
searchUrl=base_url+search_query

# %%
searchUrl
# Out:
# 'https://www.amazon.com/s?k=vivo'

# %% [markdown]
# ## Using header and referer for amazon

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
        'referer':'https://www.amazon.com/'}

# %% [markdown]
# # Using beautiful soup for web scraping

# %%
searchRes = requests.get(searchUrl,headers=header)
searchSoup=BeautifulSoup(searchRes.content)

# %%
searchSoup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
products_res=[]
for i in searchSoup.findAll("a", {'class': "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"}):
  if i["href"].find('/gp/'):
    product=dict()
    product["name"]=i["href"][1:i["href"][1:].find("/")+1]
    product['asin']=i["href"][i["href"].find("/dp/")+4:i["href"].find("/dp/")+14]
    product['url'] = f"https://www.amazon.com/{product['name']}/dp/{product['asin']}"
    products_res.append(product)
products_res
# Out:
# [{'asin': 'B009S750LA',
#   'name': 'VIVO-Monitor-Adjustable-Screens-STAND-V002',
#   'url': 'https://www.amazon.com/VIVO-Monitor-Adjustable-Screens-STAND-V002/dp/B009S750LA'},
#  {'asin': 'B0784HWPN6',
#   'name': 'VIVO-Adjustable-Converter-Tabletop-DESK-V000V',
#   'url': 'https://www.amazon.com/VIVO-Adjustable-Converter-Tabletop-DESK-V000V/dp/B0784HWPN6'},
#  {'asin': 'B07JFFZGC4',
#   'name': 'VIVO-Adjustable-Workstation-Controller-DESK-KIT-2E1B',
#   'url': 'https://www.amazon.com/VIVO-Adjustable-Workstation-Controller-DESK-KIT-2E1B/dp/B07JFFZGC4'},
#  {'asin': 'B00B21TLQU',
#   'name': 'VIVO-Monitor-Adjustable-Articulating-STAND-V001',
#   'url': 'https://www.amazon.com/VIVO-Monitor-Adjustable-Articulating-STAND-V001/dp/B00B21TLQU'},
#  {'asin': 'B075JYG2TB',
#   'name': 'VIVO-Adjustable-Converter-Workstation-DESK-V000K',
#   'url': 'https://www.amazon.com/VIVO-Adjustable-Converter-Workstation-DESK-V000K/dp/B075JYG2TB'},
#  {'asin': 'B0155LJATK',
# ...

# %%
search_responses=[]
for product in products_res:
  url = product["url"]
  print(url)
  search_responses.append(requests.get(url,headers=header))
# Out:
# https://www.amazon.com/VIVO-Monitor-Adjustable-Screens-STAND-V002/dp/B009S750LA
# https://www.amazon.com/VIVO-Adjustable-Converter-Tabletop-DESK-V000V/dp/B0784HWPN6
# https://www.amazon.com/VIVO-Adjustable-Workstation-Controller-DESK-KIT-2E1B/dp/B07JFFZGC4
# https://www.amazon.com/VIVO-Monitor-Adjustable-Articulating-STAND-V001/dp/B00B21TLQU
# https://www.amazon.com/VIVO-Adjustable-Converter-Workstation-DESK-V000K/dp/B075JYG2TB
# https://www.amazon.com/VIVO-Single-Monitor-Adjustable-STAND-V001T/dp/B0155LJATK
# https://www.amazon.com/VIVO-Adjustable-Workstation-Controller-DESK-KIT-B06D/dp/B0829FB6BV
# https://www.amazon.com/VIVO-Ergonomic-Adjustable-Controller-DESK-V122EB/dp/B08GNRS8BJ
# https://www.amazon.com/VIVO-Adjustable-Single-Monitor-PT-SD-AM01A/dp/B07JGFTGPX
# https://www.amazon.com/VIVO-Single-Laptop-Notebook-Mount/dp/B00CM9NG1W
# https://www.amazon.com/VIVO-Aluminum-Adjustable-Articulating-STAND-V001Q/dp/B01LYVCEIB
# ...

# %%
# for search_response in search_responses:
#   print(search_response.status_code)

# %%
# search_response.content

# %%
soups=[]
for search_response in search_responses:
  response=search_response
  soup=BeautifulSoup(response.content)
  soups.append(soup)

# %%
data_asin=[]
for soup in soups:
  for i in soup.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"}):
    data_asin.append(i["href"])

# %%
data_asin
# Out:
# ['/gp/customer-reviews/R2IQS9FZUW7FV3/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA',
#  '/gp/customer-reviews/R2H1KONLEH12OP/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA',
#  '/gp/customer-reviews/R1NHCS4RG7RDTQ/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA',
#  '/gp/customer-reviews/R1BTHZ8IZ9D4R0/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA',
#  '/gp/customer-reviews/R1N3S6M6Y7R008/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/REZDGFLOWKNNW/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/R1C2AV8XFUNROS/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/R3VS6ESTHCEZLY/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/RC6U2TPTFBHU6/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/RNJQWKCHA44AH/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6',
#  '/gp/customer-reviews/R22GU7UR4OMRBJ/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B07JFFZGC4',
# ...

# %%
len(data_asin)
# Out:
# 96

# %%
link=[]
for i in range(len(data_asin)):
  print(base_url[:-5]+data_asin[i])
  response=requests.get(base_url[:-5]+data_asin[i], headers=header)
  soup1=BeautifulSoup(response.content)
  link.append(soup1)
# Out:
# https://www.amazon.com/gp/customer-reviews/R2IQS9FZUW7FV3/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA
# https://www.amazon.com/gp/customer-reviews/R2H1KONLEH12OP/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA
# https://www.amazon.com/gp/customer-reviews/R1NHCS4RG7RDTQ/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA
# https://www.amazon.com/gp/customer-reviews/R1BTHZ8IZ9D4R0/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B009S750LA
# https://www.amazon.com/gp/customer-reviews/R1N3S6M6Y7R008/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6
# https://www.amazon.com/gp/customer-reviews/REZDGFLOWKNNW/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6
# https://www.amazon.com/gp/customer-reviews/R1C2AV8XFUNROS/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6
# https://www.amazon.com/gp/customer-reviews/R3VS6ESTHCEZLY/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6
# https://www.amazon.com/gp/customer-reviews/RC6U2TPTFBHU6/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0784HWPN6
# ...

# %%
# link

# %% [markdown]
# # Exctracting reviews
# (rating, name, review_head, review)

# %%
reviews=[]
for i in link:
  rev=dict()
  try:     
    rev["rating"]=float([*i.find("span",{'class':"a-icon-alt"}).children][0][:3])
    rev["name"]=[*i.find("span",{'class':"a-profile-name"}).children][0]
    rev["review_head"]=[*[*i.find("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"}).children][1].children][0]
    rev["review"]=[*[*i.find("span",{'class':"a-size-base review-text review-text-content"}).children][1].children][0]
    reviews.append(rev)
  except:
    # rev["review"]=None
    print("None")
  print(rev)
#for i in soup.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"}):
for i in reviews:
  print(i)
# Out:
# {'rating': 5.0, 'name': 'Dawson64', 'review_head': 'More stable than setting a monitor on a stand', 'review': 'I have added the monitor stand to my stand up desk.  At first, I used the 4” clamp and I liked that I was able to come up with a way to test this out.  With the 4” clamp, the\xa0'}
# {'rating': 5.0, 'name': 'Candido', 'review_head': 'Very poor quality control', 'review': "Very poor quality control.  I bought this item about a week ago and am now going to put it together.  I am doing the desk clamp install when I realize the clamp has threads for the screws BUT THE CLAMP BRACE DOES NOT!  Bigger screws will not help and shouldn't even be required.  I shouldn't have to jury rig this item.  Again, my problem is the clamp brace doesn't have threads to mate the clamp brace and the clamp together.  An email was sent just before this review.  I will update with fix once I hear from VIVO or receive a refund from them...which will be my next course of action."}
# ...

# %%
# [*link[0].find("span",{'class':"a-profile-name"}).children][0]
# [*[*link[0].find("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"}).children][1].children]

len(reviews)
# Out:
# 91

# %% [markdown]
# # Storing csv file

# %%
import csv
keys = reviews[0].keys()

with open('reviews.csv','w',newline='') as output_file:
  dict_writer = csv.DictWriter(output_file, keys)
  dict_writer.writeheader()
  dict_writer.writerows(reviews)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import re

# %%
# os.chdir('../input')
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# #Reading csv

# %%
toy_rev = pd.read_csv('reviews.csv',engine='python',index_col=False)
toy_rev.head()
# Out:
#    rating             name                                    review_head  \
# 0     5.0         Dawson64  More stable than setting a monitor on a stand
# 1     5.0          Candido                      Very poor quality control
# 2     1.0  GOB PROGRAM Y/N                               Version 2 Sucks.
# 3     5.0     Kirsten Hite         Great sturdy stand, totally adjustable
# 4     5.0      R. Castillo                              Highly recommend!
#
#                                               review
# 0  I have added the monitor stand to my stand up ...
# 1  Very poor quality control.  I bought this item...
# 2  We've bought three of these now. Apparently th...
# 3  Stand was easy to put together and clamp onto ...
# 4  Wow! I researched many desk risers and hesitan...

# %% [markdown]
# ## **Combining the review title and review body for the text corpus****

# %%
# toy_rev['review']=toy_rev['Review_Title']+toy_rev['Review']

# %%
# !python -m spacy download en_core_web_lg

# %%
import spacy
from tqdm import tqdm
nlp = spacy.load('en_core_web_lg')

# %%
competitors = []

# %% [markdown]
# #Data cleaning
# ## Removing stopwrds, defining nouns, verbs etc..

# %%
aspect_terms = []
comp_terms = []
easpect_terms = []
ecomp_terms = []
enemy = []
for x in tqdm(range(len(toy_rev['review']))):
    amod_pairs = []
    advmod_pairs = []
    compound_pairs = []
    
    xcomp_pairs = []
    neg_pairs = []
    if len(str(toy_rev['review'][x])) != 0:
        lines = str(toy_rev['review'][x]).replace('*',' ').replace('-',' ').replace('so ',' ').replace('be ',' ').replace('are ',' ').replace('just ',' ').replace('get ','').replace('were ',' ').replace('When ','').replace('when ','').replace('again ',' ').replace('where ','').replace('how ',' ').replace('has ',' ').replace('Here ',' ').replace('here ',' ').replace('now ',' ').replace('see ',' ').replace('why ',' ').split('.')       
        for line in lines:
            enem_list = []
            if len(enem_list)==0:
                doc = nlp(line)
                str1=''
                str2=''
                for token in doc:
                    if token.pos_ is 'NOUN':
                        for j in token.lefts:
                            if j.dep_ == 'compound':
                                compound_pairs.append((j.text+' '+token.text,token.text))
                            if j.dep_ is 'amod' and j.pos_ is 'ADJ': #primary condition
                                str1 = j.text+' '+token.text
                                amod_pairs.append(j.text+' '+token.text)
                                for k in j.lefts:
                                    if k.dep_ is 'advmod': #secondary condition to get adjective of adjectives
                                        str2 = k.text+' '+j.text+' '+token.text
                                        amod_pairs.append(k.text+' '+j.text+' '+token.text)
                                mtch = re.search(re.escape(str1),re.escape(str2))
                                if mtch is not None:
                                    amod_pairs.remove(str1)
                    if token.pos_ is 'VERB':
                        for j in token.lefts:
                            if j.dep_ is 'advmod' and j.pos_ is 'ADV':
                                advmod_pairs.append(j.text+' '+token.text)
                            if j.dep_ is 'neg' and j.pos_ is 'ADV':
                                neg_pairs.append(j.text+' '+token.text)
                        for j in token.rights:
                            if j.dep_ is 'advmod'and j.pos_ is 'ADV':
                                advmod_pairs.append(token.text+' '+j.text)
                    if token.pos_ is 'ADJ':
                        for j,h in zip(token.rights,token.lefts):
                            if j.dep_ is 'xcomp' and h.dep_ is not 'neg':
                                for k in j.lefts:
                                    if k.dep_ is 'aux':
                                        xcomp_pairs.append(token.text+' '+k.text+' '+j.text)
                            elif j.dep_ is 'xcomp' and h.dep_ is 'neg':
                                if k.dep_ is 'aux':
                                        neg_pairs.append(h.text +' '+token.text+' '+k.text+' '+j.text)
        pairs = list(set(amod_pairs+advmod_pairs+neg_pairs+xcomp_pairs))
        for i in range(len(pairs)):
            if len(compound_pairs)!=0:
                for comp in compound_pairs:
                    mtch = re.search(re.escape(comp[1]),re.escape(pairs[i]))
                    if mtch is not None:
                        pairs[i] = pairs[i].replace(mtch.group(),comp[0])
        
    aspect_terms.append(pairs)
    comp_terms.append(compound_pairs)
toy_rev['compound_nouns'] = comp_terms
toy_rev['aspect_keywords'] = aspect_terms
toy_rev.head()
# Out:
# 100%|██████████| 91/91 [00:04<00:00, 20.83it/s]
#    rating             name                                    review_head  \
# 0     5.0         Dawson64  More stable than setting a monitor on a stand
# 1     5.0          Candido                      Very poor quality control
# 2     1.0  GOB PROGRAM Y/N                               Version 2 Sucks.
# 3     5.0     Kirsten Hite         Great sturdy stand, totally adjustable
# 4     5.0      R. Castillo                              Highly recommend!
#
#                                               review  \
# 0  I have added the monitor stand to my stand up ...
# 1  Very poor quality control.  I bought this item...
# 2  We've bought three of these now. Apparently th...
# 3  Stand was easy to put together and clamp onto ...
# 4  Wow! I researched many desk risers and hesitan...
#
#                                       compound_nouns  \
# 0                                                 []
# ...

# %%
# !pip install vaderSentiment

# %% [markdown]
# #Importing Analyzer libraries

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
import operator
sentiment = []
for i in range(len(toy_rev)):
    score_dict={'pos':0,'neg':0,'neu':0}
    if len(toy_rev['aspect_keywords'][i])!=0: 
        for aspects in toy_rev['aspect_keywords'][i]:
            sent = analyser.polarity_scores(aspects)
            score_dict['neg'] += sent['neg']
            score_dict['pos'] += sent['pos']
        #score_dict['neu'] += sent['neu']
        sentiment.append(max(score_dict.items(), key=operator.itemgetter(1))[0])
    else:
        sentiment.append('NaN')
toy_rev['sentiment'] = sentiment
toy_rev.head()
# Out:
#    rating             name                                    review_head  \
# 0     5.0         Dawson64  More stable than setting a monitor on a stand
# 1     5.0          Candido                      Very poor quality control
# 2     1.0  GOB PROGRAM Y/N                               Version 2 Sucks.
# 3     5.0     Kirsten Hite         Great sturdy stand, totally adjustable
# 4     5.0      R. Castillo                              Highly recommend!
#
#                                               review  \
# 0  I have added the monitor stand to my stand up ...
# 1  Very poor quality control.  I bought this item...
# 2  We've bought three of these now. Apparently th...
# 3  Stand was easy to put together and clamp onto ...
# 4  Wow! I researched many desk risers and hesitan...
#
#                                       compound_nouns  \
# 0                                                 []
# 1  [(quality control, control), (desk clamp, clam...
# ...

# %% [markdown]
# #1 = positive
# #0.5 = neutral
# #0 = negative

# %%
int_sent = []
for sent in toy_rev['sentiment']:
    if sent is 'NaN':
        int_sent.append('0.5')
    elif sent is 'pos':
        int_sent.append('1')
    else:
        int_sent.append('0')
toy_rev['int_sent'] = int_sent
toy_rev.head()
# Out:
#    rating             name                                    review_head  \
# 0     5.0         Dawson64  More stable than setting a monitor on a stand
# 1     5.0          Candido                      Very poor quality control
# 2     1.0  GOB PROGRAM Y/N                               Version 2 Sucks.
# 3     5.0     Kirsten Hite         Great sturdy stand, totally adjustable
# 4     5.0      R. Castillo                              Highly recommend!
#
#                                               review  \
# 0  I have added the monitor stand to my stand up ...
# 1  Very poor quality control.  I bought this item...
# 2  We've bought three of these now. Apparently th...
# 3  Stand was easy to put together and clamp onto ...
# 4  Wow! I researched many desk risers and hesitan...
#
#                                       compound_nouns  \
# 0                                                 []
# 1  [(quality control, control), (desk clamp, clam...
# ...

# %%
toy_rev['int_sent'].unique()
# Out:
# array(['0.5', '0', '1'], dtype=object)

# %% [markdown]
# ### Here we have arbitarily taken ratings greater than 3 as positive and everything else as negative

# %%
import math
pos = []
for i in range(len(toy_rev)):
    if not math.isnan(toy_rev['rating'][i]):
        if int(toy_rev['rating'][i])>3:
            pos.append('1')
        else:
            pos.append('0')
    else:
        pos.append('0')
toy_rev['Positive Review'] = pos
toy_rev
# Out:
#     rating             name  \
# 0      5.0         Dawson64
# 1      5.0          Candido
# 2      1.0  GOB PROGRAM Y/N
# 3      5.0     Kirsten Hite
# 4      5.0      R. Castillo
# ..     ...              ...
# 86     5.0       Carlos Rey
# 87     5.0          Zounder
# 88     5.0             odin
# 89     5.0       Brandon A.
# 90     5.0             Rose
#
#                                           review_head  \
# 0       More stable than setting a monitor on a stand
# 1                           Very poor quality control
# 2                                    Version 2 Sucks.
# 3              Great sturdy stand, totally adjustable
# 4                                   Highly recommend!
# ..                                                ...
# 86                    I'm really happy with the stand
# 87                                        Works well.
# 88  Stout piece of kit, this thing! Very sturdy. G...
# 89                               Great mount! Buy it!
# ...

# %%
# for i in toy_rev["competition_comp_nouns"]:
#   if len(i)>0:
#     print(i)

# # len(toy_rev["Vehicle_Title"].unique()),len(toy_rev)

# %%
#rating = positive review
#int_sent = sentiment analysis

d = {'sent':toy_rev['Positive Review'],'sent_pred':toy_rev['int_sent']}
metric_df = pd.DataFrame(data=d)
metric_df.head(10)

from sklearn.metrics import accuracy_score 

print(accuracy_score(toy_rev['Positive Review'],toy_rev['int_sent']))
# Out:
# 0.7582417582417582

# %%
len(metric_df.sent)
# Out:
# 91

# %% [markdown]
# ## Removing NaN values in the sentiment predictions

# %%
metric_df = metric_df[metric_df.sent_pred != 'NaN']
len(metric_df.sent)
# Out:
# 91

# %%
# from sklearn.metrics import accuracy_score,auc,f1_score,recall_score,precision_score
# print('accuracy')
# print(accuracy_score(metric_df.sent, metric_df.sent_pred))
# print('f1 score')
# print(f1_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
# print('recall')
# print(recall_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
# print('precision')
# print(precision_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))

# %%
toy10 = toy_rev
toy10.head()
# Out:
#    rating             name                                    review_head  \
# 0     5.0         Dawson64  More stable than setting a monitor on a stand
# 1     5.0          Candido                      Very poor quality control
# 2     1.0  GOB PROGRAM Y/N                               Version 2 Sucks.
# 3     5.0     Kirsten Hite         Great sturdy stand, totally adjustable
# 4     5.0      R. Castillo                              Highly recommend!
#
#                                               review  \
# 0  I have added the monitor stand to my stand up ...
# 1  Very poor quality control.  I bought this item...
# 2  We've bought three of these now. Apparently th...
# 3  Stand was easy to put together and clamp onto ...
# 4  Wow! I researched many desk risers and hesitan...
#
#                                       compound_nouns  \
# 0                                                 []
# 1  [(quality control, control), (desk clamp, clam...
# ...

# %% [markdown]
# #All sentiment storing

# %%
allSentiment=[]
for i in toy10['compound_nouns']:
  for j in i:
    for k in j:
      allSentiment.append(k)
uniqueSentiment =  set(allSentiment)
uniqueSentiment, allSentiment
print(len(uniqueSentiment),len(allSentiment))
# Out:
# 297 444

# %% [markdown]
# #Cleaning all sentiments and making unique sentiments

# %%
sortedSentiments = sorted(uniqueSentiment)
print("[", end="")
for i in sortedSentiments:
  print('"'+ i+ '"', end=", ")
print("]")
# Out:
# ["29EA73 P", "3440x1440 monitor", "ASSEMBLY part", "Acer monitors", "Alienw monitor", "Amazon folks", "Asus monitor", "Benq monitor", "Dell widescreen", "Expedit system", "Friday night", "IKEA table", "Ik table", "K monitor", "LG P", "Max extension", "P", "Phillips screw", "Predator x34", "Prime delivery", "Programming presets", "Quick", "RL2455S monitor", "Simple assembly", "TV", "TV rig", "Topo floor", "USB stick", "Uplift desk", "VIVO Quick", "VIVO base", "VIVO products", "Velcro strap", "VeriDesk models", "Vivo monitor", "Zowie monitor", "adjustable", "adjustment capability", "adjustment screw", "al adjustable", "alcohol wipes", "angle", "angle screw", "arm", "arm articulation", "arms", "articulation", "aspect monitor", "assembly", "assembly time", "assist arm", "attachment", "bar", "base", "bike", "board", "board surround", "bolt", "brace", "budmonitor mount", "build quality", "c clamp", "cable management", "cable routing", "capability", "cardboard core", "case", "center pole", 
# ...

# %%
# !pip install ipywidgets 
# # To enable `ipywidgets`
# !jupyter nbextension enable --py widgetsnbextension

# %% [markdown]
# #Making  dropdown widget

# %%
import pandas as pd
from ipywidgets import widgets
from IPython.display import display

# %%
w = widgets.Dropdown(
    options=sortedSentiments,
)

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print("changed to %s" % change['new'])
        aspect = change['new']
        selectedReviews=[]
        for i in range(len(toy10)):
          for j in toy10["compound_nouns"][i]:
              # print(j, toy10["compound_nouns"][i][j])
              for k in j:
                # print(k)
                if aspect == k:
                  # print(k)
                  selectedReviews.append(float(toy10["int_sent"][i]))
        print(sum(selectedReviews)/len(selectedReviews), "out of", len(selectedReviews), "reviews")
w.observe(on_change)

display(w)
# Out:
# Dropdown(options=('29EA73 P', '3440x1440 monitor', 'ASSEMBLY part', 'Acer monitors', 'Alienw monitor', 'Amazon…
# changed to Amazon folks
# 1.0 out of 1 reviews
# changed to Expedit system
# 1.0 out of 1 reviews
# changed to Alienw monitor
# 1.0 out of 1 reviews
